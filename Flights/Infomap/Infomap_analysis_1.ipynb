# %%
import pandas as pd
import numpy as np
np.set_printoptions(threshold=100000)

# %%
flights = pd.read_pickle('C:\\Users\\utente\\Documents\\DSSC_IIyear\\Voli\\Dataframe\\S1_flights_sectorhours.pkl')
flights
# Out:
#                                  flight  \
# 0        A6RTS_OMDW_EGGW_20170901055500
# 1       AAB249_EBKT_LFMN_20170901070500
# 2       AAB249_LFMN_LIEO_20170901090500
# 3       AAB25C_LOWW_UUMO_20170901143500
# 4       AAB571_EBBR_EGNV_20170901050500
# ...                                 ...
# 29912   XLF056_LFPG_MMUN_20170901153100
# 29913  XLF1451_LFML_LFPG_20170901030500
# 29914   XRO546_LFMD_EGCC_20170901180000
# 29915   XRO552_EHAM_LFMD_20170901150000
# 29916    Z3MKD_LWSK_EDDF_20170901130000
#
#                                             sector_hours
# 0      [LTAAAEU67_0800_0900_E, LTAAAEU67_0900_1000_E,...
# 1      [EBBUWLS_0620_0700_E, EBBUWLS_0700_0800_E, EBB...
# 2      [LFMMMNST_0800_0900_E, LFMMMNST_0900_1000_E, L...
# 3      [LZBBL33_1400_1500_E, LZBBL33_1500_1600_E, LZB...
# 4      [EBBUNWC_0530_0600_E, EBBUNWC_0600_0620_E, EBB...
# ...                                                  ...
# 29912  [LFFFTH_1500_1600_E, LFFFTH_1600_1700_E, LFFFU...
# ...

# %%
dictFlights = {i:flights['flight'].loc[i-1] for i in range(1,len(flights)+1)}
dictFlights
# Out:
# {1: 'A6RTS_OMDW_EGGW_20170901055500',
#  2: 'AAB249_EBKT_LFMN_20170901070500',
#  3: 'AAB249_LFMN_LIEO_20170901090500',
#  4: 'AAB25C_LOWW_UUMO_20170901143500',
#  5: 'AAB571_EBBR_EGNV_20170901050500',
#  6: 'AAB678_LEIB_LPPR_20170901100000',
#  7: 'AAB696_EBLG_LFPT_20170901140000',
#  8: 'AAB713_EBKT_EHBK_20170901103000',
#  9: 'AAB713_EDDV_EHBK_20170901183500',
#  10: 'AAB713_EHBK_EBKT_20170901194500',
#  11: 'AAB713_EHBK_EDDV_20170901121600',
#  12: 'AAD901A_EGNR_EGKA_20170901070000',
#  13: 'AAD901B_EGKA_EGNR_20170901153000',
#  14: 'AAF221_LFPO_DAAG_20170901181500',
#  15: 'AAF222_DAAG_LFPO_20170901095500',
#  16: 'AAF223_LFPO_DAAG_20170901114500',
#  17: 'AAF224_DAAG_LFPO_20170901145000',
#  18: 'AAF241_LFPO_DAON_20170901130500',
#  19: 'AAF242_DAON_LFPO_20170901165500',
#  20: 'AAF255_LFPG_DAAG_20170901100000',
#  21: 'AAF256_DAAG_LFPO_20170901083000',
#  22: 'AAF257_LFPO_DAAG_20170901143000',
#  23: 'AAF258_DAAG_LFPO_20170901183000',
#  24: 'AAF259_LFPO_DAAG_20170901093000',
# ...

# %%
data = pd.read_csv('infomap_output_W.txt', sep=" ", header=None)
data.columns = ["Flight", "Cluster", "drop"]
data
# Out:
#        Flight  Cluster      drop
# 0        3979        1  0.000337
# 1       25239        1  0.000272
# 2       24911        1  0.000236
# 3        3730        1  0.000229
# 4       17179        1  0.000220
# ...       ...      ...       ...
# 29912   22848       70  0.000000
# 29913   25106       71  0.000000
# 29914   25107       72  0.000000
# 29915   26455       73  0.000000
# 29916   27309       74  0.000000
#
# [29917 rows x 3 columns]

# %%
min(data['Flight'])
data
# Out:
#                                  Flight  Cluster      drop
# 0      BAW63GV_EGLL_LGAV_20170901055500        1  0.000337
# 1       THY1RD_EGLL_LTBA_20170901054500        1  0.000272
# 2       TCX230_EGCC_LTBS_20170901052800        1  0.000236
# 3      BAW25LR_EGKK_LGIR_20170901062100        1  0.000229
# 4       NAX1PY_ESSA_LEPA_20170901043000        1  0.000220
# ...                                 ...      ...       ...
# 29912   SBI955_UUDD_UGTB_20170901105500       70  0.000000
# 29913   TGZ785_UGTB_ULLI_20170901172000       71  0.000000
# 29914   TGZ786_ULLI_UGTB_20170901214500       72  0.000000
# 29915  TJT052P_LFMD_LFML_20170901120000       73  0.000000
# 29916  TVS2456_LFSB_LFST_20170901110000       74  0.000000
#
# [29917 rows x 3 columns]

# %%
for i in range(0, len(data)):
    data['Flight'].loc[i] = dictFlights[(data['Flight'].loc[i])]
# Out:
# C:\Users\utente\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
mydata2 = data.groupby(['Cluster'])
mydata2 = mydata2['Flight'].unique()
mydata2 = pd.DataFrame({'CLUSTER':mydata2.index, 'FLIGHTS':mydata2.values})
mydata2
# Out:
#     CLUSTER                                            FLIGHTS
# 0         1  [BAW63GV_EGLL_LGAV_20170901055500, THY1RD_EGLL...
# 1         2  [FIN5AQ_EFHK_LEMG_20170901173500, RYR4PC_EKCH_...
# 2         3  [ETD20_EGLL_OMAA_20170901135800, QFA10_EGLL_OM...
# 3         4  [SAS4676_LEAL_ENGM_20170901083500, AFL2620_UUE...
# 4         5  [ETD10Y_EGLL_OMAA_20170901083500, ELY312_EGGW_...
# ..      ...                                                ...
# 69       70                  [SBI955_UUDD_UGTB_20170901105500]
# 70       71                  [TGZ785_UGTB_ULLI_20170901172000]
# 71       72                  [TGZ786_ULLI_UGTB_20170901214500]
# 72       73                 [TJT052P_LFMD_LFML_20170901120000]
# 73       74                 [TVS2456_LFSB_LFST_20170901110000]
#
# [74 rows x 2 columns]

# %%
mydata2['SIZE']=0
for i in range(0,len(mydata2)):
    mydata2['SIZE'].loc[i] = len(mydata2['FLIGHTS'].loc[i])
mydata2
# Out:
#     CLUSTER                                            FLIGHTS  SIZE
# 0         1  [BAW63GV_EGLL_LGAV_20170901055500, THY1RD_EGLL...  6826
# 1         2  [FIN5AQ_EFHK_LEMG_20170901173500, RYR4PC_EKCH_...  6212
# 2         3  [ETD20_EGLL_OMAA_20170901135800, QFA10_EGLL_OM...  4167
# 3         4  [SAS4676_LEAL_ENGM_20170901083500, AFL2620_UUE...  2743
# 4         5  [ETD10Y_EGLL_OMAA_20170901083500, ELY312_EGGW_...  1919
# ..      ...                                                ...   ...
# 69       70                  [SBI955_UUDD_UGTB_20170901105500]     1
# 70       71                  [TGZ785_UGTB_ULLI_20170901172000]     1
# 71       72                  [TGZ786_ULLI_UGTB_20170901214500]     1
# 72       73                 [TJT052P_LFMD_LFML_20170901120000]     1
# 73       74                 [TVS2456_LFSB_LFST_20170901110000]     1
#
# [74 rows x 3 columns]

# %%
mydata2[mydata2['SIZE']>1]
# Out:
#     CLUSTER                                            FLIGHTS  SIZE
# 0         1  [BAW63GV_EGLL_LGAV_20170901055500, THY1RD_EGLL...  6826
# 1         2  [FIN5AQ_EFHK_LEMG_20170901173500, RYR4PC_EKCH_...  6212
# 2         3  [ETD20_EGLL_OMAA_20170901135800, QFA10_EGLL_OM...  4167
# 3         4  [SAS4676_LEAL_ENGM_20170901083500, AFL2620_UUE...  2743
# 4         5  [ETD10Y_EGLL_OMAA_20170901083500, ELY312_EGGW_...  1919
# 5         6  [PRI557_EKCH_LEMG_20170901155000, AEE8SE_EGLL_...  1296
# 6         7  [IBK8KW_GCLP_EDDK_20170901121500, RYR2506_EDDB...   872
# 7         8  [FDX5392_RJAA_LFPG_20170901002500, VLG8549_EFH...  1010
# 8         9  [THY61V_LTAI_ULLI_20170901044000, NWS5873_ULLI...   889
# 9        10  [NWS5874_LTAI_ULLI_20170901110000, THY8TY_ULLI...   661
# 10       11  [CAI7YF_EPWA_LTAI_20170901160500, SDM5703_ULLI...   495
# 11       12  [EIN3CH_EIDW_EDDM_20170901151831, RYR3HE_EGSS_...   610
# 12       13  [BAW5_EGLL_RJAA_20170901144500, BEL8YB_EBBR_ES...   989
# ...

# %%
singletons = mydata2[mydata2['SIZE']==1]
singletons
# Out:
#     CLUSTER                             FLIGHTS  SIZE
# 30       31   [AUA99J_LOWW_LOWK_20170901151500]     1
# 31       32   [AUA93J_LOWW_LOWK_20170901210500]     1
# 32       33   [CAI040_EHEH_EHBK_20170901074000]     1
# 33       34  [AUA935T_LOWW_LOWK_20170901075500]     1
# 34       35  [AUA929K_LOWW_LOWK_20170901181500]     1
# 35       36    [AOS54_EGBJ_EGFF_20170901092000]     1
# 36       37    [EGL08_EGHH_EGTE_20170901181500]     1
# 37       38   [EZE610_EGFF_EGOV_20170901063500]     1
# 38       39   [EZE612_EGFF_EGOV_20170901142500]     1
# 39       40  [FPO750F_LFMN_LFML_20170901190500]     1
# 40       41   [FPO759_LFML_LFMN_20170901004000]     1
# 41       42   [AOJ75D_LDVA_LQBK_20170901053000]     1
# 42       43  [GAC018Z_LFSB_LSZH_20170901081000]     1
# 43       44  [GDK01CA_LOWW_LOWK_20170901100000]     1
# 44       45   [HHE60B_EHLX_EHKD_20170901130900]     1
# 45       46   [HNL05A_EHLL_EHKD_20170901114000]     1
# ...

# %%
singletons.reset_index(drop=True, inplace=True)
singletons['CLUSTER'] = 'None'
singletons
# Out:
# C:\Users\utente\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    CLUSTER                             FLIGHTS  SIZE
# 0     None   [AUA99J_LOWW_LOWK_20170901151500]     1
# 1     None   [AUA93J_LOWW_LOWK_20170901210500]     1
# 2     None   [CAI040_EHEH_EHBK_20170901074000]     1
# 3     None  [AUA935T_LOWW_LOWK_20170901075500]     1
# 4     None  [AUA929K_LOWW_LOWK_20170901181500]     1
# 5     None    [AOS54_EGBJ_EGFF_20170901092000]     1
# 6     None    [EGL08_EGHH_EGTE_20170901181500]     1
# 7     None   [EZE610_EGFF_EGOV_20170901063500]     1
# 8     None   [EZE612_EGFF_EGOV_20170901142500]     1
# 9     None  [FPO750F_LFMN_LFML_20170901190500]     1
# ...

# %%
for i in range(0,len(singletons)):
    singletons['FLIGHTS'].loc[i] = ((singletons['FLIGHTS'].loc[i]).tolist())[0]
singletons
# Out:
# C:\Users\utente\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    CLUSTER                           FLIGHTS  SIZE
# 0     None   AUA99J_LOWW_LOWK_20170901151500     1
# 1     None   AUA93J_LOWW_LOWK_20170901210500     1
# 2     None   CAI040_EHEH_EHBK_20170901074000     1
# 3     None  AUA935T_LOWW_LOWK_20170901075500     1
# 4     None  AUA929K_LOWW_LOWK_20170901181500     1
# 5     None    AOS54_EGBJ_EGFF_20170901092000     1
# 6     None    EGL08_EGHH_EGTE_20170901181500     1
# 7     None   EZE610_EGFF_EGOV_20170901063500     1
# 8     None   EZE612_EGFF_EGOV_20170901142500     1
# 9     None  FPO750F_LFMN_LFML_20170901190500     1
# 10    None   FPO759_LFML_LFMN_20170901004000     1
# ...

# %%
type(singletons['FLIGHTS'].loc[1])
# Out:
# str

# %%
singletons = singletons.groupby(['CLUSTER'])
singletons = singletons['FLIGHTS'].unique()
singletons = pd.DataFrame({'CLUSTER':singletons.index, 'FLIGHTS':singletons.values})
singletons['SIZE'] = len(singletons['FLIGHTS'].loc[0])
singletons
# Out:
#   CLUSTER                                            FLIGHTS  SIZE
# 0    None  [AUA99J_LOWW_LOWK_20170901151500, AUA93J_LOWW_...    44

# %%
clusters = mydata2[mydata2['SIZE']!=1]
clusters
# Out:
#     CLUSTER                                            FLIGHTS  SIZE
# 0         1  [BAW63GV_EGLL_LGAV_20170901055500, THY1RD_EGLL...  6826
# 1         2  [FIN5AQ_EFHK_LEMG_20170901173500, RYR4PC_EKCH_...  6212
# 2         3  [ETD20_EGLL_OMAA_20170901135800, QFA10_EGLL_OM...  4167
# 3         4  [SAS4676_LEAL_ENGM_20170901083500, AFL2620_UUE...  2743
# 4         5  [ETD10Y_EGLL_OMAA_20170901083500, ELY312_EGGW_...  1919
# 5         6  [PRI557_EKCH_LEMG_20170901155000, AEE8SE_EGLL_...  1296
# 6         7  [IBK8KW_GCLP_EDDK_20170901121500, RYR2506_EDDB...   872
# 7         8  [FDX5392_RJAA_LFPG_20170901002500, VLG8549_EFH...  1010
# 8         9  [THY61V_LTAI_ULLI_20170901044000, NWS5873_ULLI...   889
# 9        10  [NWS5874_LTAI_ULLI_20170901110000, THY8TY_ULLI...   661
# 10       11  [CAI7YF_EPWA_LTAI_20170901160500, SDM5703_ULLI...   495
# 11       12  [EIN3CH_EIDW_EDDM_20170901151831, RYR3HE_EGSS_...   610
# 12       13  [BAW5_EGLL_RJAA_20170901144500, BEL8YB_EBBR_ES...   989
# ...

# %%
clusters['CLUSTER'] = range(0,len(clusters))
clusters
# Out:
# C:\Users\utente\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     CLUSTER                                            FLIGHTS  SIZE
# 0         0  [BAW63GV_EGLL_LGAV_20170901055500, THY1RD_EGLL...  6826
# 1         1  [FIN5AQ_EFHK_LEMG_20170901173500, RYR4PC_EKCH_...  6212
# 2         2  [ETD20_EGLL_OMAA_20170901135800, QFA10_EGLL_OM...  4167
# 3         3  [SAS4676_LEAL_ENGM_20170901083500, AFL2620_UUE...  2743
# 4         4  [ETD10Y_EGLL_OMAA_20170901083500, ELY312_EGGW_...  1919
# 5         5  [PRI557_EKCH_LEMG_20170901155000, AEE8SE_EGLL_...  1296
# ...

# %%
a = clusters['SIZE'].sum()
b = singletons['SIZE'].loc[0]
c = 29917
print(a, b, c, a+b==c)
# Out:
# 29873 44 29917 True

# %%
infomap_clusters_1 = pd.concat([clusters, singletons])
infomap_clusters_1
# Out:
#    CLUSTER                                            FLIGHTS  SIZE
# 0        0  [BAW63GV_EGLL_LGAV_20170901055500, THY1RD_EGLL...  6826
# 1        1  [FIN5AQ_EFHK_LEMG_20170901173500, RYR4PC_EKCH_...  6212
# 2        2  [ETD20_EGLL_OMAA_20170901135800, QFA10_EGLL_OM...  4167
# 3        3  [SAS4676_LEAL_ENGM_20170901083500, AFL2620_UUE...  2743
# 4        4  [ETD10Y_EGLL_OMAA_20170901083500, ELY312_EGGW_...  1919
# 5        5  [PRI557_EKCH_LEMG_20170901155000, AEE8SE_EGLL_...  1296
# 6        6  [IBK8KW_GCLP_EDDK_20170901121500, RYR2506_EDDB...   872
# 7        7  [FDX5392_RJAA_LFPG_20170901002500, VLG8549_EFH...  1010
# 8        8  [THY61V_LTAI_ULLI_20170901044000, NWS5873_ULLI...   889
# 9        9  [NWS5874_LTAI_ULLI_20170901110000, THY8TY_ULLI...   661
# 10      10  [CAI7YF_EPWA_LTAI_20170901160500, SDM5703_ULLI...   495
# 11      11  [EIN3CH_EIDW_EDDM_20170901151831, RYR3HE_EGSS_...   610
# 12      12  [BAW5_EGLL_RJAA_20170901144500, BEL8YB_EBBR_ES...   989
# ...

# %%
infomap_clusters_1.reset_index(drop=True, inplace=True)
infomap_clusters_1
# Out:
#    CLUSTER                                            FLIGHTS  SIZE
# 0        0  [BAW63GV_EGLL_LGAV_20170901055500, THY1RD_EGLL...  6826
# 1        1  [FIN5AQ_EFHK_LEMG_20170901173500, RYR4PC_EKCH_...  6212
# 2        2  [ETD20_EGLL_OMAA_20170901135800, QFA10_EGLL_OM...  4167
# 3        3  [SAS4676_LEAL_ENGM_20170901083500, AFL2620_UUE...  2743
# 4        4  [ETD10Y_EGLL_OMAA_20170901083500, ELY312_EGGW_...  1919
# 5        5  [PRI557_EKCH_LEMG_20170901155000, AEE8SE_EGLL_...  1296
# 6        6  [IBK8KW_GCLP_EDDK_20170901121500, RYR2506_EDDB...   872
# 7        7  [FDX5392_RJAA_LFPG_20170901002500, VLG8549_EFH...  1010
# 8        8  [THY61V_LTAI_ULLI_20170901044000, NWS5873_ULLI...   889
# 9        9  [NWS5874_LTAI_ULLI_20170901110000, THY8TY_ULLI...   661
# 10      10  [CAI7YF_EPWA_LTAI_20170901160500, SDM5703_ULLI...   495
# 11      11  [EIN3CH_EIDW_EDDM_20170901151831, RYR3HE_EGSS_...   610
# 12      12  [BAW5_EGLL_RJAA_20170901144500, BEL8YB_EBBR_ES...   989
# ...

# %%
infomap_clusters_1['SIZE'].sum()
# Out:
# 29917

# %%
infomap_clusters_1.to_csv('C:\\Users\\utente\\Documents\\DSSC_IIyear\\Voli\\Infomap\\infomap_clusters_W.csv', header=True, index=False)

# %%
mylist = mydata2['FLIGHTS'].loc[24]
#flights.loc[mydata2['FLIGHTS'].loc[2]]
#flights.loc[mydata2['FLIGHTS'].loc[4]]

# %%
flights[flights['flight'].isin(mylist)]
# Out:
#                                  flight  \
# 166     ABY292_UGTB_OMSJ_20170901194500
# 169     ABY295_OMSJ_UGTB_20170901183500
# 686    AFL1868_UUEE_UDYZ_20170901174000
# 689    AFL1892_UUEE_UGTB_20170901191000
# 1791   AHY8226_UGTB_UBBB_20170901212000
# 11934  FDB8529_OMDB_UGSB_20170901185500
# 15419   KZR140_UGTB_UAAA_20170901193000
# 17559   NGT748_UUOO_UDYZ_20170901185000
# 23521  SVR2814_UDYZ_ULLI_20170901195000
# 25096  TGZ1727_UGTB_OISS_20170901202500
# 28811   VSV842_UGTB_UATE_20170901201000
#
#                                             sector_hours
# 166    [UDDDALL_1900_2000_E, UDDDALL_2000_2100_E, UGG...
# 169    [UDDDALL_2000_2100_E, UDDDALL_2100_2200_E, UGG...
# 686    [UGGGEAS_1900_2000_E, UGGGEAS_2000_2100_E, UDD...
# 689    [UGGGEAS_2100_2200_E, UGGGEAS_2200_2300_E, UGG...
# 1791          [UGGGEAS_2100_2200_E, UGGGEAS_2200_2300_E]
# 11934  [UDDDALL_2100_2200_E, UDDDALL_2200_2300_E, UGG...
# 15419         [UGGGEAS_1900_2000_E, UGGGEAS_2000_2100_E]
# ...
