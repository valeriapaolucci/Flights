# %%
import pandas as pd
import numpy as np
import csv

# %%
output = pd.read_csv('infomap_clusters_W.csv')
output
# Out:
#    CLUSTER                                            FLIGHTS  SIZE
# 0        0  ['BAW63GV_EGLL_LGAV_20170901055500' 'THY1RD_EG...  6826
# 1        1  ['FIN5AQ_EFHK_LEMG_20170901173500' 'RYR4PC_EKC...  6212
# 2        2  ['ETD20_EGLL_OMAA_20170901135800' 'QFA10_EGLL_...  4167
# 3        3  ['SAS4676_LEAL_ENGM_20170901083500' 'AFL2620_U...  2743
# 4        4  ['ETD10Y_EGLL_OMAA_20170901083500' 'ELY312_EGG...  1919
# 5        5  ['PRI557_EKCH_LEMG_20170901155000' 'AEE8SE_EGL...  1296
# 6        6  ['IBK8KW_GCLP_EDDK_20170901121500' 'RYR2506_ED...   872
# 7        7  ['FDX5392_RJAA_LFPG_20170901002500' 'VLG8549_E...  1010
# 8        8  ['THY61V_LTAI_ULLI_20170901044000' 'NWS5873_UL...   889
# 9        9  ['NWS5874_LTAI_ULLI_20170901110000' 'THY8TY_UL...   661
# 10      10  ['CAI7YF_EPWA_LTAI_20170901160500' 'SDM5703_UL...   495
# 11      11  ['EIN3CH_EIDW_EDDM_20170901151831' 'RYR3HE_EGS...   610
# 12      12  ['BAW5_EGLL_RJAA_20170901144500' 'BEL8YB_EBBR_...   989
# 13      13  ['DLH2YX_EGCC_EDDF_20170901082500' 'RYR1277_EG...   302
# 14      14  ['SAS1464_EKCH_ENGM_20170901071500' 'IBK3221_E...   366
# 15      15  ['VJT545_LMML_GCLP_20170901122500' 'IBB6801_GV...    99
# 16      16  ['LTR524_ENST_ENTC_20170901145500' 'FVK243_ENB...   113
# 17      17  ['BMR1364_EKEB_EGPD_20170901084000' 'BEE2972_E...    61
# 18      18  ['RSC412_GCXO_GCFV_20170901090000' 'SEV761_GCF...    48
# 19      19  ['LOT8119_EETN_ESSA_20170901032500' 'NAX80M_EF...    40
# 20      20  ['LTR812_ENLK_ENML_20170901110000' 'LTR313_ENT...    27
# 21      21  ['SVR2703_UUDD_UDYZ_20170901092500' 'UTA873_UU...    63
# 22      22  ['FVK202_ENHF_ENTC_20170901044500' 'WIF51C_ENN...    21
# 23      23  ['BPS651_EFHK_EFSA_20170901050500' 'FIN3GW_EFH...    15
# 24      24  ['AFL1868_UUEE_UDYZ_20170901174000' 'SVR2814_U...    11
# 25      25  ['REM370_ESGG_EYVI_20170901000100' 'BID2A_EVRA...     3
# 26      26  ['DOP615_EKEB_EKDB_20170901161500' 'DOP641_EKE...     6
# 27      27  ['DOP602_EKGC_EKEB_20170901070000' 'DOP604_EKT...     4
# 28      28  ['DOP606_EKDB_EKEB_20170901101500' 'DOP911_EKE...     3
# 29      29  ['LTR211_ENBN_ENRA_20170901225000' 'LTR212_ENR...     2
# 30    None  ['AUA99J_LOWW_LOWK_20170901151500' 'AUA93J_LOW...    44

# %%
output = output.replace('\n','', regex=True)

# %%
output['CLUSTER'] = '("' + output['CLUSTER'].astype(str) + '")'
output = output.replace("'", '"', regex=True)
output
# Out:
#      CLUSTER                                            FLIGHTS  SIZE
# 0      ("0")  ["BAW63GV_EGLL_LGAV_20170901055500" "THY1RD_EG...  6826
# 1      ("1")  ["FIN5AQ_EFHK_LEMG_20170901173500" "RYR4PC_EKC...  6212
# 2      ("2")  ["ETD20_EGLL_OMAA_20170901135800" "QFA10_EGLL_...  4167
# 3      ("3")  ["SAS4676_LEAL_ENGM_20170901083500" "AFL2620_U...  2743
# 4      ("4")  ["ETD10Y_EGLL_OMAA_20170901083500" "ELY312_EGG...  1919
# 5      ("5")  ["PRI557_EKCH_LEMG_20170901155000" "AEE8SE_EGL...  1296
# 6      ("6")  ["IBK8KW_GCLP_EDDK_20170901121500" "RYR2506_ED...   872
# 7      ("7")  ["FDX5392_RJAA_LFPG_20170901002500" "VLG8549_E...  1010
# 8      ("8")  ["THY61V_LTAI_ULLI_20170901044000" "NWS5873_UL...   889
# 9      ("9")  ["NWS5874_LTAI_ULLI_20170901110000" "THY8TY_UL...   661
# 10    ("10")  ["CAI7YF_EPWA_LTAI_20170901160500" "SDM5703_UL...   495
# 11    ("11")  ["EIN3CH_EIDW_EDDM_20170901151831" "RYR3HE_EGS...   610
# 12    ("12")  ["BAW5_EGLL_RJAA_20170901144500" "BEL8YB_EBBR_...   989
# 13    ("13")  ["DLH2YX_EGCC_EDDF_20170901082500" "RYR1277_EG...   302
# 14    ("14")  ["SAS1464_EKCH_ENGM_20170901071500" "IBK3221_E...   366
# 15    ("15")  ["VJT545_LMML_GCLP_20170901122500" "IBB6801_GV...    99
# 16    ("16")  ["LTR524_ENST_ENTC_20170901145500" "FVK243_ENB...   113
# 17    ("17")  ["BMR1364_EKEB_EGPD_20170901084000" "BEE2972_E...    61
# 18    ("18")  ["RSC412_GCXO_GCFV_20170901090000" "SEV761_GCF...    48
# 19    ("19")  ["LOT8119_EETN_ESSA_20170901032500" "NAX80M_EF...    40
# 20    ("20")  ["LTR812_ENLK_ENML_20170901110000" "LTR313_ENT...    27
# 21    ("21")  ["SVR2703_UUDD_UDYZ_20170901092500" "UTA873_UU...    63
# 22    ("22")  ["FVK202_ENHF_ENTC_20170901044500" "WIF51C_ENN...    21
# 23    ("23")  ["BPS651_EFHK_EFSA_20170901050500" "FIN3GW_EFH...    15
# 24    ("24")  ["AFL1868_UUEE_UDYZ_20170901174000" "SVR2814_U...    11
# 25    ("25")  ["REM370_ESGG_EYVI_20170901000100" "BID2A_EVRA...     3
# 26    ("26")  ["DOP615_EKEB_EKDB_20170901161500" "DOP641_EKE...     6
# 27    ("27")  ["DOP602_EKGC_EKEB_20170901070000" "DOP604_EKT...     4
# 28    ("28")  ["DOP606_EKDB_EKEB_20170901101500" "DOP911_EKE...     3
# 29    ("29")  ["LTR211_ENBN_ENRA_20170901225000" "LTR212_ENR...     2
# 30  ("None")  ["AUA99J_LOWW_LOWK_20170901151500" "AUA93J_LOW...    44

# %%
with open('infomap_clusters_W.dat', 'a') as the_file:
    for i in range(0,len(output)):
        the_file.write('\t' + str(output['CLUSTER'].loc[i]) + " " + str(output['FLIGHTS'].loc[i]) + '\n')

# %%
output['FLIGHTS'].loc[28]
#output['SIZE'].sum()
# Out:
# '["DOP606_EKDB_EKEB_20170901101500" "DOP911_EKEB_EKSI_20170901094500" "DOP605_EKEB_EKDB_20170901090000"]'

# %%
#output.to_csv('C:\\Users\\utente\\Documents\\DSSC_IIyear\\Voli\\Network\\output___1.dat', header=True, index=False)

# %%
#prova = pd.read_csv('output___1.dat')
#prova

# %%
#output = output[['CLUSTER','FLIGHTS']]

# %%
#output.to_csv('C:\\Users\\utente\\Documents\\DSSC_IIyear\\Voli\\Infomap\\infomap_clusters___3.csv', header=True, index=False)

# %%
#output.to_csv('C:\\Users\\utente\\Documents\\DSSC_IIyear\\Voli\\Infomap\\infomap_clusters___3.dat', sep=',', header=False, index=False)

# %%
#data = pd.read_csv('infomap_clusters___3.dat', header=None, sep=',')

# %%
#data
