# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
flights = pd.read_pickle('C:\\Users\\utente\\Documents\\DSSC_IIyear\\Voli\\Dataframe\\S1_flights_sectorhours.pkl')
flights
# Out:
#                                  flight  \
# 0        A6RTS_OMDW_EGGW_20170901055500
# 1       AAB249_EBKT_LFMN_20170901070500
# 2       AAB249_LFMN_LIEO_20170901090500
# 3       AAB25C_LOWW_UUMO_20170901143500
# 4       AAB571_EBBR_EGNV_20170901050500
# ...                                 ...
# 29912   XLF056_LFPG_MMUN_20170901153100
# 29913  XLF1451_LFML_LFPG_20170901030500
# 29914   XRO546_LFMD_EGCC_20170901180000
# 29915   XRO552_EHAM_LFMD_20170901150000
# 29916    Z3MKD_LWSK_EDDF_20170901130000
#
#                                             sector_hours
# 0      [LTAAAEU67_0800_0900_E, LTAAAEU67_0900_1000_E,...
# 1      [EBBUWLS_0620_0700_E, EBBUWLS_0700_0800_E, EBB...
# 2      [LFMMMNST_0800_0900_E, LFMMMNST_0900_1000_E, L...
# 3      [LZBBL33_1400_1500_E, LZBBL33_1500_1600_E, LZB...
# 4      [EBBUNWC_0530_0600_E, EBBUNWC_0600_0620_E, EBB...
# ...                                                  ...
# 29912  [LFFFTH_1500_1600_E, LFFFTH_1600_1700_E, LFFFU...
# ...

# %%
G = nx.Graph()
G.add_nodes_from(range(0,len(flights)))
#G.add_nodes_from(range(0,12))

G

# %%
import pickle
with open ('C:\\Users\\utente\\Documents\\DSSC_IIyear\\Voli\\Edgelist\\edgelist_W', 'rb') as fp:
    edgelist_W = pickle.load(fp)
    
edgelist_W
# Out:
# [(2, 1, 0.84869957),
#  (17, 15, 2.2673642999999997),
#  (17, 16, 1.6157135),
#  (18, 13, 4.665175),
#  (18, 16, 2.2487636),
#  (19, 14, 6.628338),
#  (20, 14, 31.90101),
#  (20, 19, 3.2574400000000003),
#  (21, 16, 12.205085),
#  (21, 17, 4.672688),
#  (21, 18, 2.8748259999999997),
#  (22, 13, 12.811537),
#  (22, 18, 10.760598),
#  (23, 5, 1.4070757999999999),
#  (23, 14, 10.192578999999999),
#  (23, 19, 25.824562),
#  (23, 20, 6.009279),
#  (24, 15, 5.513992),
#  (24, 16, 1.2721345),
#  (24, 17, 4.6365943),
#  (24, 21, 0.7315059),
#  (25, 1, 1.9359533),
#  (25, 14, 0.74700564),
#  (25, 20, 1.7269164000000001),
#  (26, 5, 1.7559328999999997),
#  (26, 14, 19.458460000000002),
#  (26, 19, 7.337791999999999),
#  (26, 20, 12.661635),
#  (26, 23, 11.897285),
#  (27, 16, 5.3726125),
#  (27, 17, 8.216514),
#  (27, 18, 2.2620847),
#  (27, 21, 21.193745),
#  (27, 24, 4.2839885),
#  (28, 13, 8.797701),
#  (28, 18, 16.0308),
#  (28, 21, 0.6127412),
#  (28, 22, 19.996449),
# ...

# %%
len(edgelist_W)*2
# Out:
# 25596802

# %%
G.add_weighted_edges_from(edgelist_W)

# %%
#plt.subplot(121)
#nx.draw(G, with_labels=True, font_weight='bold')

# %%
nx.write_pajek(G, "infomap_input_W.net")
